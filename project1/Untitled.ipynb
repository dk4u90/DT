# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.set_index('Country',inplace=True)

# %%
df.head(2)
# Out:
#                      Region  Happiness Rank  Happiness Score  Standard Error  \
# Country
# Switzerland  Western Europe               1            7.587         0.03411
# Iceland      Western Europe               2            7.561         0.04884
#
#              Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Country
# Switzerland                   1.39651  1.34951                   0.94143
# Iceland                       1.30232  1.40223                   0.94784
#
#              Freedom  Trust (Government Corruption)  Generosity  \
# Country
# Switzerland  0.66557                        0.41978     0.29678
# Iceland      0.62877                        0.14145     0.43630
#
#              Dystopia Residual
# Country
# Switzerland            2.51738
# Iceland                2.70201

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, Switzerland to Togo
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Region                         158 non-null    object
#  1   Happiness Rank                 158 non-null    int64
#  2   Happiness Score                158 non-null    float64
#  3   Standard Error                 158 non-null    float64
#  4   Economy (GDP per Capita)       158 non-null    float64
#  5   Family                         158 non-null    float64
#  6   Health (Life Expectancy)       158 non-null    float64
#  7   Freedom                        158 non-null    float64
#  8   Trust (Government Corruption)  158 non-null    float64
#  9   Generosity                     158 non-null    float64
#  10  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 13.6+ KB

# %%
df.isnull().sum()
# Out:
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.sort_values(by='Happiness Rank',ascending=True).head(10)
# Out:
#                                 Region  Happiness Rank  Happiness Score  \
# Country
# Switzerland             Western Europe               1            7.587
# Iceland                 Western Europe               2            7.561
# Denmark                 Western Europe               3            7.527
# Norway                  Western Europe               4            7.522
# Canada                   North America               5            7.427
# Finland                 Western Europe               6            7.406
# Netherlands             Western Europe               7            7.378
# Sweden                  Western Europe               8            7.364
# New Zealand  Australia and New Zealand               9            7.286
# Australia    Australia and New Zealand              10            7.284
#
#              Standard Error  Economy (GDP per Capita)   Family  \
# Country
# Switzerland         0.03411                   1.39651  1.34951
# ...

# %%
df.sort_values(by='Happiness Rank',ascending=False).head(10)
# Out:
#                                        Region  Happiness Rank  \
# Country
# Togo                       Sub-Saharan Africa             158
# Burundi                    Sub-Saharan Africa             157
# Syria         Middle East and Northern Africa             156
# Benin                      Sub-Saharan Africa             155
# Rwanda                     Sub-Saharan Africa             154
# Afghanistan                     Southern Asia             153
# Burkina Faso               Sub-Saharan Africa             152
# Ivory Coast                Sub-Saharan Africa             151
# Guinea                     Sub-Saharan Africa             150
# Chad                       Sub-Saharan Africa             149
#
#               Happiness Score  Standard Error  Economy (GDP per Capita)  \
# Country
# Togo                    2.839         0.06727                   0.20868
# Burundi                 2.905         0.08658                   0.01530
# ...

# %%
df.groupby('Region')['Happiness Score'].describe().sort_values(by='mean',ascending=True).head(10)
# Out:
#                                  count      mean       std    min      25%  \
# Region
# Sub-Saharan Africa                40.0  4.202800  0.609557  2.839  3.75600
# Southern Asia                      7.0  4.580857  0.570526  3.575  4.39250
# Southeastern Asia                  9.0  5.317444  0.950020  3.819  4.87600
# Central and Eastern Europe        29.0  5.332931  0.570446  4.218  4.95900
# Middle East and Northern Africa   20.0  5.406900  1.101382  3.006  4.70775
# Eastern Asia                       6.0  5.626167  0.554053  4.874  5.22350
# Latin America and Caribbean       22.0  6.144682  0.728560  4.518  5.84050
# Western Europe                    21.0  6.689619  0.824582  4.857  6.30200
# North America                      2.0  7.273000  0.217789  7.119  7.19600
# Australia and New Zealand          2.0  7.285000  0.001414  7.284  7.28450
#
#                                    50%      75%    max
# Region
# Sub-Saharan Africa               4.272  4.58075  5.477
# ...

# %%
df.groupby('Region')['Happiness Score'].describe().sort_values(by='mean',ascending=False).head(10)
# Out:
#                                  count      mean       std    min      25%  \
# Region
# Australia and New Zealand          2.0  7.285000  0.001414  7.284  7.28450
# North America                      2.0  7.273000  0.217789  7.119  7.19600
# Western Europe                    21.0  6.689619  0.824582  4.857  6.30200
# Latin America and Caribbean       22.0  6.144682  0.728560  4.518  5.84050
# Eastern Asia                       6.0  5.626167  0.554053  4.874  5.22350
# Middle East and Northern Africa   20.0  5.406900  1.101382  3.006  4.70775
# Central and Eastern Europe        29.0  5.332931  0.570446  4.218  4.95900
# Southeastern Asia                  9.0  5.317444  0.950020  3.819  4.87600
# Southern Asia                      7.0  4.580857  0.570526  3.575  4.39250
# Sub-Saharan Africa                40.0  4.202800  0.609557  2.839  3.75600
#
#                                    50%      75%    max
# Region
# Australia and New Zealand        7.285  7.28550  7.286
# ...

# %%
plt.figure(figsize=(24,5))
sns.countplot(df['Happiness Score'])
# Out:
# C:\Users\dk4u\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Happiness Score', ylabel='count'>

# %%
df['Happiness Score'].head(10).plot(xticks=np.arange(9),kind='barh')
plt.xlabel("Happiness Score")
plt.title('Happiness Score of the top 10 Countries')
# Out:
# Text(0.5, 1.0, 'Happiness Score of the top 10 Countries')

# %%
df[['Economy (GDP per Capita)', 'Family','Health (Life Expectancy)', 'Freedom', 'Generosity', 'Trust (Government Corruption)', 'Dystopia Residual']].head(10).plot(kind='barh',xticks=np.arange(9), stacked=True, figsize= (10, 10))
plt.xlabel("Happiness Score")
plt.title('Happiness Score of the top 10 Countries')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
df.head(2)
# Out:
#                      Region  Happiness Rank  Happiness Score  Standard Error  \
# Country
# Switzerland  Western Europe               1            7.587         0.03411
# Iceland      Western Europe               2            7.561         0.04884
#
#              Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Country
# Switzerland                   1.39651  1.34951                   0.94143
# Iceland                       1.30232  1.40223                   0.94784
#
#              Freedom  Trust (Government Corruption)  Generosity  \
# Country
# Switzerland  0.66557                        0.41978     0.29678
# Iceland      0.62877                        0.14145     0.43630
#
#              Dystopia Residual
# Country
# Switzerland            2.51738
# Iceland                2.70201

# %%
fig, axes = plt.subplots(nrows=2, ncols=2,constrained_layout=True,figsize=(12,8))
sns.barplot(x='Economy (GDP per Capita)',y='Region',data=df.nlargest(10,'Economy (GDP per Capita)'),ax=axes[0,0],palette="Blues_d")
sns.barplot(x='Generosity' ,y='Region',data=df.nlargest(10,'Generosity'),ax=axes[0,1],palette="YlGn")
sns.barplot(x='Health (Life Expectancy)' ,y='Region',data=df.nlargest(10,'Health (Life Expectancy)'),ax=axes[1,0],palette='OrRd')
sns.barplot(x='Freedom' ,y='Region',data=df.nlargest(10,'Freedom'),ax=axes[1,1],palette='YlOrBr')
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Region'>

# %%
sns.histplot(df['Happiness Score'],kde=True)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Count'>

# %% [markdown]
# As we can see below, the Happiness Score has values above 2.85 and below 7.76. So there is no single country which has a Happiness Score above 8.

# %%
sns.histplot(df['Trust (Government Corruption)'],kde=True)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Count'>

# %% [markdown]
# Distribution of Perceptions of corruption rightly skewed that means very less number of the country has high perceptions of corruption. That means most of the country has corruption problems.

# %%
sns.scatterplot(df['Happiness Score'],df['Trust (Government Corruption)'])
# Out:
# C:\Users\dk4u\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Happiness Score', ylabel='Trust (Government Corruption)'>

# %% [markdown]
# Perceptions of corruption data have highly skewed no wonder why the data has a weak linear relationship. Still, as we can see in the scatter plot, most of the data points are on the left side, and most of the countries with low perceptions of corruption have a Happiness Score between 4 to 6. Countries with high perception scores have a high Happiness Score above 7.

# %%
df.head(2)
# Out:
#                      Region  Happiness Rank  Happiness Score  Standard Error  \
# Country
# Switzerland  Western Europe               1            7.587         0.03411
# Iceland      Western Europe               2            7.561         0.04884
#
#              Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Country
# Switzerland                   1.39651  1.34951                   0.94143
# Iceland                       1.30232  1.40223                   0.94784
#
#              Freedom  Trust (Government Corruption)  Generosity  \
# Country
# Switzerland  0.66557                        0.41978     0.29678
# Iceland      0.62877                        0.14145     0.43630
#
#              Dystopia Residual
# Country
# Switzerland            2.51738
# Iceland                2.70201

# %%
sns.pairplot(data=df, hue='Region', size = 5,
                  x_vars=['Happiness Score'],
                  y_vars=['Economy (GDP per Capita)', 'Family','Health (Life Expectancy)', 'Freedom', 'Generosity', 'Trust (Government Corruption)', 'Dystopia Residual'])
# Out:
# C:\Users\dk4u\anaconda3\lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# In the scatterplots, we see that GDP, Health, and Support are quite linearly correlated with some noise. We find the auto-correlation of Corruption fascinating here, where everything is terrible, but if the corruption is high, the distribution is all over the place. It seems to be just a negative indicator of a threshold

# %%
df.corr(method="pearson")["Happiness Score"].sort_values(ascending=False)
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Dystopia Residual                0.530474
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Standard Error                  -0.177254
# Happiness Rank                  -0.992105
# Name: Happiness Score, dtype: float64

# %%
df.corr(method="pearson")["Happiness Score"].abs().sort_values(ascending=False)
# Out:
# Happiness Score                  1.000000
# Happiness Rank                   0.992105
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Dystopia Residual                0.530474
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Standard Error                   0.177254
# Name: Happiness Score, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %% [markdown]
# It looks like GDP, Health, and Support are strongly correlated with the Happiness score. Freedom correlates quite well with the Happiness score; however, Freedom connects quite well with all data. Corruption still has a mediocre correlation with the Happiness score

# %%
df.head(3)
# Out:
#                      Region  Happiness Rank  Happiness Score  Standard Error  \
# Country
# Switzerland  Western Europe               1            7.587         0.03411
# Iceland      Western Europe               2            7.561         0.04884
# Denmark      Western Europe               3            7.527         0.03328
#
#              Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Country
# Switzerland                   1.39651  1.34951                   0.94143
# Iceland                       1.30232  1.40223                   0.94784
# Denmark                       1.32548  1.36058                   0.87464
#
#              Freedom  Trust (Government Corruption)  Generosity  \
# Country
# Switzerland  0.66557                        0.41978     0.29678
# Iceland      0.62877                        0.14145     0.43630
# Denmark      0.64938                        0.48357     0.34139
#
#              Dystopia Residual
# Country
# ...

# %%
df['Region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df['Region']=LE.fit_transform(df['Region'])

# %%
df.head()
# Out:
#              Region  Happiness Rank  Happiness Score  Standard Error  \
# Country
# Switzerland       9               1            7.587         0.03411
# Iceland           9               2            7.561         0.04884
# Denmark           9               3            7.527         0.03328
# Norway            9               4            7.522         0.03880
# Canada            5               5            7.427         0.03553
#
#              Economy (GDP per Capita)   Family  Health (Life Expectancy)  \
# Country
# Switzerland                   1.39651  1.34951                   0.94143
# Iceland                       1.30232  1.40223                   0.94784
# Denmark                       1.32548  1.36058                   0.87464
# Norway                        1.45900  1.33095                   0.88521
# Canada                        1.32629  1.32261                   0.90563
#
#              Freedom  Trust (Government Corruption)  Generosity  \
# Country
# ...

# %%
x=df.drop(['Happiness Score'],axis=True)
y=df[['Happiness Score']]

# %%
# MULTIPLE LR
import statsmodels.api as sm
x_sm = x = sm.add_constant(x)
model = sm.OLS(y,x_sm)
model.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Happiness Score   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.591e+08
# Date:                Sun, 16 May 2021   Prob (F-statistic):               0.00
# Time:                        09:29:36   Log-Likelihood:                 1073.0
# No. Observations:                 158   AIC:                            -2124.
# Df Residuals:                     147   BIC:                            -2090.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
LR=LinearRegression()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42)
LR.fit(x_train,y_train)
y_pred=LR.predict(x_test)

# %% [markdown]
# ##### Conclusion
# It seems like the common criticism for “The World Happiness Report” is quite valid. A high focus on GDP and strongly correlated features such as family and life expectancy.
